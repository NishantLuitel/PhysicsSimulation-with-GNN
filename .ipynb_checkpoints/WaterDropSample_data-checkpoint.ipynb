# %% [markdown]
# #

# %%
import torch

# %%
import numpy as np

b = np.load('dataverse_files/gns-water-drop-sample/valid.npz/valid.npz',allow_pickle=True)

# %%
b.files
# Out:
# ['simulation_trajectory_0', 'simulation_trajectory_1']

# %%
b['simulation_trajectory_0'][0].shape
# Out:
# (1000, 482, 2)

# %%
b['simulation_trajectory_0'][0][:,:,:].min(),b['simulation_trajectory_1']
# Out:
# (0.09128882,
#  array([array([[[0.74429494, 0.23800676],
#                 [0.7454113 , 0.25064564],
#                 [0.73348325, 0.24668458],
#                 ...,
#                 [0.72893965, 0.3649757 ],
#                 [0.6579555 , 0.3837185 ],
#                 [0.68486166, 0.40589687]],
#
#                [[0.74429494, 0.23791343],
#                 [0.7454113 , 0.2505524 ],
#                 [0.73348325, 0.24659126],
#                 ...,
#                 [0.72893965, 0.36488235],
#                 [0.6579555 , 0.38362503],
#                 [0.68486166, 0.4058034 ]],
#
#                [[0.74429494, 0.23775873],
#                 [0.7454113 , 0.25039786],
#                 [0.73348325, 0.24643655],
#                 ...,
#                 [0.72893965, 0.3647277 ],
#                 [0.6579555 , 0.38347018],
#                 [0.68486166, 0.40564856]],
#
#                ...,
#
#                [[0.86372465, 0.11859949],
#                 [0.8595056 , 0.12345862],
# ...

# %%
list(b['simulation_trajectory_0'])
# Out:
# [array([[[0.75829923, 0.44826713],
#          [0.7454544 , 0.45095435],
#          [0.7449756 , 0.44183245],
#          ...,
#          [0.62795556, 0.57371867],
#          [0.65486157, 0.595897  ],
#          [0.8335973 , 0.5922025 ]],
#
#         [[0.75829923, 0.44817367],
#          [0.7454544 , 0.45086086],
#          [0.7449756 , 0.44173896],
#          ...,
#          [0.62795556, 0.57362545],
#          [0.65486157, 0.5958038 ],
#          [0.8335973 , 0.59210926]],
#
#         [[0.75829923, 0.44801903],
#          [0.7454544 , 0.45070612],
#          [0.7449756 , 0.44158432],
#          ...,
#          [0.62795556, 0.5734707 ],
#          [0.65486157, 0.5956492 ],
#          [0.8335973 , 0.59195465]],
#
#         ...,
#
#         [[0.33160162, 0.11266454],
#          [0.29101986, 0.12312532],
#          [0.27601764, 0.12427168],
#          ...,
#          [0.88404447, 0.13665481],
#          [0.62096435, 0.12545596],
#          [0.78433824, 0.10699398]],
#
# ...

# %%
len(b['simulation_trajectory_1'][0][0])
# Out:
# 362
